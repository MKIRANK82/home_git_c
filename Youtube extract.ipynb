# %%
#!pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# Set up the WebDriver
def get_data(url,filename):
    driver = webdriver.Chrome()  # or use webdriver.Firefox() if you're using Firefox
    playlist_url = url
    driver.get(playlist_url)
    
    # Scroll to load all videos in the playlist
    last_height = driver.execute_script("return document.documentElement.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        time.sleep(2)  # Wait for more videos to load
        new_height = driver.execute_script("return document.documentElement.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    
    # Extract video titles
    video_titles = driver.find_elements(By.XPATH, '//*[@id="video-title"]')
    
    lines=""
    for title in video_titles:
        
        print(title.text)
        if "guided breathing mantra" in title.text.lower():
            lines+=title.text
            lines+="\n"
    
    
    # Close the WebDriver
    driver.quit()
    
    with open(filename,"w") as f:
        f.write(lines)

# %%
get_data("https://www.youtube.com/watch?v=WjXnSSRNsWI&list=PLPoeiOPNJEsjAuqIjJ7uYaragB77GlpZt","breathing level 4.txt")
# Out:
# Guided Breathing Mantra (4 - 4 - 4 - 4) Pranayama Yoga Breathing Exercise (Level 4 - Volume 1)
# Guided Breathing Mantra (4 - 4 - 4 - 8) Pranayama Yoga Breathing Exercise (Level 4 - Volume 2)
# Guided Breathing Mantra (4 - 4 - 4 - 12) Pranayama Yoga Breathing Exercise (Level 4 - Volume 3)
# Guided Breathing Mantra (4 - 4 - 8 - 4) Pranayama Yoga Breathing Exercise (Level 4 - Volume 4)
# Guided Breathing Mantra (4 - 4 - 8 - 8) Pranayama Yoga Breathing Exercise (Level 4 - Volume 5)
# Guided Breathing Mantra (4 - 4 - 8 - 12) Pranayama Yoga Breathing Exercise (Level 4 - Volume 6)
# Guided Breathing Mantra (4 - 4 - 12 - 4) Pranayama Yoga Breathing Exercise (Level 4 - Volume 7)
# Guided Breathing Mantra (4 - 4 - 12 - 8) Pranayama Yoga Breathing Exercise (Level 4 - Volume 8)
# Guided Breathing Mantra (4 - 4 - 12 - 12) Pranayama Yoga Breathing Exercise (Level 4 - Volume 9)
# Guided Breathing Mantra (4 - 8 - 4 - 4) Pranayama Yoga Breathing Exercise (Level 4 - Volume 10)
# ...

# %%
lines
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 lines
#
# NameError: name 'lines' is not defined

# %%
text="Temp of AAA"
text.lower()
# Out:
# 'temp of aaa'

# %%
print(playlist_elements.html)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(playlist_elements.html)
#
# AttributeError: 'list' object has no attribute 'html'
